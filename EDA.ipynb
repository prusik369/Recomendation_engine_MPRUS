# %%
from Utils_eda import *

# %%
df = pd.read_csv('data/ratings.csv')

# %%
# Add a readable datetime column
df = add_datetime_column(df)
# Out:
# Column 'datetime' added to dataframe.

# %%
# Show min and max dates
show_time_range(df)
# Out:
# Time range:
# Min: 1970-01-01 00:00:00
# Max: 2016-10-16 17:57:24

# %%
# Check missing values
check_missing_values(df)
show_rows_with_nulls(df)
# Out:
# Missing values per column:
# user_id       1
# product_id    4
# rating        0
# timestamp     0
# datetime      0
# dtype: int64
# Row index 18097 has NaN in columns: ['product_id']
# Row index 18098 has NaN in columns: ['product_id']
# Row index 18099 has NaN in columns: ['product_id']
# Row index 18100 has NaN in columns: ['product_id']
# Row index 99999 has NaN in columns: ['user_id']
#        user_id  product_id  rating   timestamp            datetime
# 18097    119.0         NaN     3.0   913211320 1998-12-09 13:48:40
# 18098    119.0         NaN     3.0   913211248 1998-12-09 13:47:28
# 18099    119.0         NaN     3.0   945993582 1999-12-23 23:59:42
# 18100    119.0         NaN     3.0   960671726 2000-06-10 21:15:26
# 99999      NaN      6268.0     2.5  1065579370 2003-10-08 02:16:10

# %%
count_unique_values(df)

# %%
# Histogram and numeric counts of ratings
plot_rating_counts(df)
# Out:
# Number of ratings per value:
# rating
# -1.0         1
#  0.5      1101
#  1.0      3326
#  1.5      1687
#  2.0      7271
#  2.5      4449
#  3.0     20064
#  3.5     10538
#  4.0     28748
#  4.5      7723
#  5.0     15095
#  99.0        1
# Name: count, dtype: int64

# %%
# Show statistics for the 'rating' column
show_column_stats(df, "rating")
# Out:
# Stats for column 'rating':
# Min: -1.0
# Max: 99.0
# Mean: 3.544508219671213
# Median: 4.0
# Unique values: 12
# ALL values: {4.0: 28748, 3.0: 20064, 5.0: 15095, 3.5: 10538, 4.5: 7723, 2.0: 7271, 2.5: 4449, 1.0: 3326, 1.5: 1687, 0.5: 1101, 99.0: 1, -1.0: 1}

# %%
# Number of ratings over time (monthly)
plot_ratings_over_time(df, freq="M")
# Out:
# c:\Python\Recomendation_engine_MPRUS\Utils_eda.py:73: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   counts = df.set_index(date_col).resample(freq)["rating"].count()

# %%
# Count number of rows per year
count_rows_per_year(df)
# Out:
# Number of rows per year:
# datetime
# 1970        4
# 1995        3
# 1996     6239
# 1997     3294
# 1998     1825
# 1999     5901
# 2000    13869
# 2001     4658
# 2002     3938
# 2003     4462
# 2004     4654
# 2005     7161
# 2006     7493
# 2007     1548
# 2008     3676
# 2009     3434
# 2010     2518
# 2011     4450
# 2012     3849
# 2013     1969
# 2014     2224
# 2015     6610
# 2016     6225
# dtype: int64

# %%
# Horizontal bar charts for top and bottom users
plot_top_bottom_users_horizontal(df, top_n=30)

# %%
# Horizontal bar charts for top and bottom products
plot_top_bottom_products_horizontal(df, top_n=20)

# %%
# Count products by number of ratings
count_products_by_num_ratings(df)
# Out:
# Number of products by number of ratings:
# rating
# 1      3063
# 2      1202
# 3       755
# 4       550
# 5       397
#        ...
# 291       1
# 304       1
# 311       1
# 324       1
# 341       1
# Name: count, Length: 185, dtype: int64

# %%
# sparsity matrix
plot_sparsity_matrix(df)

# %%
# user-user similarity heatmap
plot_user_similarity_heatmap(df)

# %%
# item-item similarity heatmap
plot_item_similarity_heatmap(df)

# %%
plot_item_similarity_heatmap(df, top_n=100)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7848\3153303886.py:26: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = subset.pivot_table(index="product_id", columns="user_id", values="rating")

# %%
plot_user_similarity_heatmap(df, top_n=200)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7848\3904408630.py:30: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = subset.pivot_table(index="user_id", columns="product_id", values="rating")

# %%
# Yearly average rating trend
plot_avg_rating_per_year(df)

# %%
# Filter dataset to include ratings from 1995 onward
df_from_1995 = df[df["datetime"].dt.year >= 1995] 
# Plot rating trends for the top N most-rated products (from 1995+)
plot_top_products_trends(df_from_1995, top_n=10)

# %%
# Histogram of the number of ratings per item
plot_ratings_per_product_hist(df)

# %%
# Histogram of the number of ratings per user
plot_ratings_per_user_hist(df)

# %%
plot_ratings_per_product_hist(df)

# %%
count_sparse_users_products(df, 10,)
# Out:
# Number of users with less than 10 ratings: 0
# Number of products with less than 100 ratings: 8915

# %%
count_products_by_num_ratings(df, max_ratings=1000)
# Out:
# Products with 1 to 1000 ratings:
#   1 ratings: 3063 products
#   2 ratings: 1202 products
#   3 ratings: 755 products
#   4 ratings: 550 products
#   5 ratings: 397 products
#   6 ratings: 305 products
#   7 ratings: 206 products
#   8 ratings: 187 products
#   9 ratings: 156 products
#   10 ratings: 162 products
#   11 ratings: 133 products
#   12 ratings: 101 products
#   13 ratings: 113 products
#   14 ratings: 98 products
#   15 ratings: 72 products
#   16 ratings: 68 products
#   17 ratings: 71 products
#   18 ratings: 59 products
#   19 ratings: 65 products
#   20 ratings: 56 products
#   21 ratings: 62 products
#   22 ratings: 65 products
#   23 ratings: 54 products
#   24 ratings: 37 products
#   25 ratings: 34 products
#   26 ratings: 45 products
#   27 ratings: 35 products
#   28 ratings: 32 products
#   29 ratings: 35 products
#   30 ratings: 27 products
#   31 ratings: 32 products
#   32 ratings: 24 products
#   33 ratings: 23 products
#   34 ratings: 20 products
# ...

# %%
count_unique_values(df)
# Out:
# Unique values per column:
#   user_id: 671
#   product_id: 9066
#   rating: 12

# %%
df_filtered = analyze_cutoff_impact(df, product_min_ratings=8, user_low_n=10)
# Out:
# === 1. Product rating counts BEFORE filtering ===
# count    9066.000000
# mean       11.030223
# std        24.050668
# min         1.000000
# 25%         1.000000
# 50%         3.000000
# 75%         9.000000
# max       341.000000
# Name: count, dtype: float64
#
# Products with < 8 ratings: 6478
#
# Records BEFORE filtering: 100004
# Records AFTER filtering: 84811
# Removed: 15193 records (15.19%)
#
# === 2. User activity (ratings per user) AFTER filtering ===
# Total unique users after filtering: 671
#
# === Lowest 10 activity levels (explained) ===
#
# This table shows how many users belong to the lowest activity groups.
# Columns:
# - 'ratings_per_user' → How many ratings a user has (1, 2, 3, ...)
# - 'num_users' → How many users fall into that activity level
#
# Example:
# If the row says:
#     ratings_per_user = 1 → num_users = 250
# It means that 250 users created exactly 1 rating.
#
#    ratings_per_user  num_users
# 0                10          1
# ...

# %%
detect_duplicates(df)
# Out:
# === DUPLICATE REPORT ===
# Exact duplicates: 0 rows
# Duplicate user-product pairs: 4 rows
# {'exact_duplicates': Empty DataFrame
#  Columns: [user_id, product_id, rating, timestamp, datetime]
#  Index: [],
#  'duplicate_user_product_pairs':        user_id  product_id  rating  timestamp            datetime
#  18098    119.0         NaN     3.0  913211248 1998-12-09 13:47:28
#  18097    119.0         NaN     3.0  913211320 1998-12-09 13:48:40
#  18099    119.0         NaN     3.0  945993582 1999-12-23 23:59:42
#  18100    119.0         NaN     3.0  960671726 2000-06-10 21:15:26}
