# %%
from Utils_eda import *

# %%
from Utils_eda import *

# %%
# 1. Add a readable datetime column
df = add_datetime_column(df)
# Out:
# Column 'datetime' added to dataframe.

# %%
# 2. Show the date range
show_time_range(df)
# Out:
# Time range:
# Min: 1970-01-01 00:00:00
# Max: 2016-10-16 17:57:24

# %%
# 3. Check for missing values
check_missing_values(df)
show_rows_with_nulls(df)
# Out:
# Missing values per column:
# user_id       1
# product_id    4
# rating        0
# timestamp     0
# datetime      0
# dtype: int64
# Row index 18097 has NaN in columns: ['product_id']
# Row index 18098 has NaN in columns: ['product_id']
# Row index 18099 has NaN in columns: ['product_id']
# Row index 18100 has NaN in columns: ['product_id']
# Row index 99999 has NaN in columns: ['user_id']
#        user_id  product_id  rating   timestamp            datetime
# 18097    119.0         NaN     3.0   913211320 1998-12-09 13:48:40
# 18098    119.0         NaN     3.0   913211248 1998-12-09 13:47:28
# 18099    119.0         NaN     3.0   945993582 1999-12-23 23:59:42
# 18100    119.0         NaN     3.0   960671726 2000-06-10 21:15:26
# 99999      NaN      6268.0     2.5  1065579370 2003-10-08 02:16:10

# %%
# 4. Plot histogram and numeric counts of ratings
plot_rating_counts(df)

# %%
# 5. Show statistics for the 'rating' column
show_column_stats(df, "rating")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 2
#       1 # 5. Show statistics for the 'rating' column
# ----> 2 show_column_stats(df, "rating")
#
# NameError: name 'show_column_stats' is not defined

# %%
# 6. Plot number of ratings over time (monthly)
plot_ratings_over_time(df, freq="M")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 2
#       1 # 6. Plot number of ratings over time (monthly)
# ----> 2 plot_ratings_over_time(df, freq="M")
#
# NameError: name 'plot_ratings_over_time' is not defined

# %%
# 7. Count number of rows per year
count_rows_per_year(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 2
#       1 # 7. Count number of rows per year
# ----> 2 count_rows_per_year(df)
#
# NameError: name 'count_rows_per_year' is not defined
